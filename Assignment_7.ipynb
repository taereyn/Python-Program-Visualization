# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install xlrd
# Out:
# ...
# You are using pip version 19.0.3, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
def norm_1(sp):
    sp_scaled = sp.copy()
    for column in sp_scaled.columns:
        sp_scaled[column] = (sp_scaled[column]-sp_scaled[column].abs().min())/((sp_scaled[column].abs().max()-sp_scaled[column].abs().min()))
    
    return sp_scaled

# %%
sheets_1 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q001')
df1 = pd.DataFrame(sheets_1, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df1_1 = df1.iloc[0:26]
df1_new = norm_1(df1_1)

sheets_2 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q002')
df2 = pd.DataFrame(sheets_2, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df2_1 = df2.iloc[0:26]
df2_new = norm_1(df2_1)

sheets_3 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q003')
df3 = pd.DataFrame(sheets_3, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df3_1 = df3.iloc[0:26]
df3_new = norm_1(df3_1)

sheets_4 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q004') 
df4 = pd.DataFrame(sheets_4, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df4_1 = df4.iloc[0:26]
df4_new = norm_1(df4_1)

sheets_5 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q005')
df5 = pd.DataFrame(sheets_5, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df5_1 = df5.iloc[0:26]
df5_new = norm_1(df5_1)

sheets_6 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q006')
df6 = pd.DataFrame(sheets_6, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df6_1 = df6.iloc[0:26]
df6_new = norm_1(df6_1)

sheets_7 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q007')
df7 = pd.DataFrame(sheets_7, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df7_1 = df7.iloc[0:26]
df7_new = norm_1(df7_1)

sheets_8 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q008')
df8 = pd.DataFrame(sheets_8, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df8_1 = df8.iloc[0:26]
df8_new = norm_1(df8_1)

sheets_9 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q009')
df9 = pd.DataFrame(sheets_9, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df9_1 = df9.iloc[0:26]
df9_new = norm_1(df9_1)

sheets_10 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q010')
df10 = pd.DataFrame(sheets_10, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df10_1 = df10.iloc[0:26]
df10_new = norm_1(df10_1)

sheets_11 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q011')
df11 = pd.DataFrame(sheets_11, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df11_1 = df11.iloc[0:26]
df11_new = norm_1(df11_1)

sheets_12 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q012')
df12 = pd.DataFrame(sheets_12, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df12_1 = df12.iloc[0:26]
df12_new = norm_1(df12_1)

sheets_13 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q013')
df13 = pd.DataFrame(sheets_13, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])      
df13_1 = df13.iloc[0:26]
df13_new = norm_1(df13_1)

sheets_14 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q014')
df14 = pd.DataFrame(sheets_14, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df14_1 = df14.iloc[0:26]
df14_new = norm_1(df14_1)

sheets_15 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q015')
df15 = pd.DataFrame(sheets_15, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df15_1 = df15.iloc[0:26]
df15_new = norm_1(df15_1)

sheets_16 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q016')
df16 = pd.DataFrame(sheets_16, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df16_1 = df16.iloc[0:26]
df16_new = norm_1(df16_1)

sheets_17 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q017')
df17 = pd.DataFrame(sheets_17, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df17_1 = df17.iloc[0:26]
df17_new = norm_1(df17_1)

sheets_18 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q018')
df18 = pd.DataFrame(sheets_18, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df18_1 = df18.iloc[0:26]
df18_new = norm_1(df18_1)

sheets_19 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q019')
df19 = pd.DataFrame(sheets_19, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df19_1 = df19.iloc[0:26]
df19_new = norm_1(df19_1)

sheets_20 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q020')
df20 = pd.DataFrame(sheets_20, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df20_1 = df20.iloc[0:26]
df20_new = norm_1(df20_1)

sheets_21 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q021')
df21 = pd.DataFrame(sheets_21, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df21_1 = df21.iloc[0:26]
df21_new = norm_1(df21_1)

sheets_22 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q022')
df22 = pd.DataFrame(sheets_22, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df22_1 = df22.iloc[0:26]
df22_new = norm_1(df22_1)

sheets_23 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q023')
df23 = pd.DataFrame(sheets_23, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df23_1 = df23.iloc[0:26]
df23_new = norm_1(df23_1)

sheets_24 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q024')
df24 = pd.DataFrame(sheets_24, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df24_1 = df24.iloc[0:26]
df24_new = norm_1(df24_1)

sheets_25 = pd.read_excel("/Users/cerser/Downloads/EDAData.xlsx", sheet_name='Q025')
df25 = pd.DataFrame(sheets_25, columns= ['Time','GSR_Fingers_Raw','Q_Fingers_Raw'])
df25_1 = df25.iloc[0:26]
df25_new = norm_1(df25_1)

# %%
import matplotlib.pyplot as plt
#x='GSR_Fingers_Raw'
#y= 'Q_Fingers_Raw'
ax = df25_new.plot()

df24_new.plot(ax=ax)

df23_new.plot(ax=ax)

df22_new.plot(ax=ax)

df21_new.plot(ax=ax)

df20_new.plot(ax=ax)

df19_new.plot(ax=ax)

df18_new.plot(ax=ax)

df17_new.plot(ax=ax)

df16_new.plot(ax=ax)

df15_new.plot(ax=ax)

df14_new.plot(ax=ax)

df13_new.plot(ax=ax)

df12_new.plot(ax=ax)

df11_new.plot(ax=ax)

df10_new.plot(ax=ax)

df9_new.plot(ax=ax)

df8_new.plot(ax=ax)

df7_new.plot(ax=ax)

df6_new.plot(ax=ax)

df5_new.plot(ax=ax)

df4_new.plot(ax=ax)

df3_new.plot(ax=ax)

df2_new.plot(ax=ax)

df1_new.plot(ax=ax)

fig= ax.get_figure()
fig.savefig('/Users/cerser/Downloads/hw7.pdf')

# %%
df10 = pd.DataFrame(sheets_10, columns= ['GSR_Fingers_Raw'])
df10_1_2 = df10.iloc[0:26]
df10_new_1 = norm_1(df10_1_2)

df10 = pd.DataFrame(sheets_10, columns= ['Q_Fingers_Raw'])
df10_1_3 = df10.iloc[0:26]
df10_new_2 = norm_1(df10_1_3)

ax1 = df10_new_1.plot()
ax2 = df10_new_2.plot()

ax1.annotate('local max', xy=(0,-36.666667), xytext=(0.3, -35.666667),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax1.annotate('local min', xy=(25,-37.666667), xytext=(25.3, -36.666667),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax2.annotate('local max', xy=(0, 1), xytext=(0.3, 2),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax2.annotate('local min', xy=(1, 0), xytext=(0.3, 1),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
# Out:
# Text(0.3,1,'local min')

# %%
sns.scatterplot(x='GSR_Fingers_Raw', y = 'Time', data =df10_new_1, color = 'g',marker = 'v')

# %%
a = sns.scatterplot(x='Q_Fingers_Raw', y = 'Time', data =df10_new_2, color = 'b',marker = '8')

# %%
import seaborn as sns
sns.scatterplot(x='GSR_Fingers_Raw', y = 'Time', data =df10_new_1, color = 'g',marker = 'v', hue = 'GSR_Fingers_Raw')
plt.title("GSR_Fingers_Raw vs Time")
# Out:
# Text(0.5,1,'GSR_Fingers_Raw vs Time')

# %%
a = sns.scatterplot(x='Q_Fingers_Raw', y = 'Time', data =df10_new_2, color = 'b',marker = '8', hue = 'Q_Fingers_Raw')
plt.title("Q_Fingers_Raw vs Time")
# Out:
# Text(0.5,1,'Q_Fingers_Raw vs Time')
